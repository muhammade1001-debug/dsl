# %%
import nltk
import pandas as pd

# %%
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  l
# Packages:
# Error connecting to server: [Errno -3] Temporary failure in name resolution
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  l
# Packages:

# %%
messages=[line.rstrip() for line in open('/home/kmea/Downloads/archive (2)/spam.csv',encoding='latin-1')]
print(len(messages))
# Out:
# 5575

# %%
messages[0]
# Out:
# 'v1,v2,,,'

# %%
for mess_no,message in enumerate(messages[:10]):
 print(mess_no,message)
 print('\n')
# Out:
# 0 v1,v2,,,
#
#
# 1 ham,"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",,,
#
#
# 2 ham,Ok lar... Joking wif u oni...,,,
#
#
# 3 spam,Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's,,,
#
#
# 4 ham,U dun say so early hor... U c already then say...,,,
#
#
# 5 ham,"Nah I don't think he goes to usf, he lives around here though",,,
#
#
# 6 spam,"FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, å£1.50 to rcv",,,
#
#
# 7 ham,Even my brother is not like to speak with me. They treat me like aids patent.,,,
#
#
# 8 ham,As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune,,,
#
#
# ...

# %%
messages[1]
# Out:
# 'ham,"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",,,'

# %%
messages=pd.read_csv("/home/kmea/Downloads/archive (2)/spam.csv",sep="\t",names=["message","label"],encoding='latin-1')

# %%
messages.head()
# Out:
#                                              message  label
# 0                                           v1,v2,,,    NaN
# 1  ham,"Go until jurong point, crazy.. Available ...    NaN
# 2               ham,Ok lar... Joking wif u oni...,,,    NaN
# 3  spam,Free entry in 2 a wkly comp to win FA Cup...    NaN
# 4  ham,U dun say so early hor... U c already then...    NaN
